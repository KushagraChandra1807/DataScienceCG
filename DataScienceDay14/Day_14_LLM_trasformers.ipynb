# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator(
    "Artificial Intelligence will",
    max_new_tokens=30,
    num_return_sequences=1
)

print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Artificial Intelligence will be able to detect, identify, and respond to any of a range of different social messages. It is expected to be able to see and respond to

# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”

from transformers import pipeline

# Load GPT-2 text generation model
generator = pipeline("text-generation", model="gpt2")

# Prompt from the game developer
prompt = "The hero enters the ancient forest and discovers"

# Generate story continuation
result = generator(
    prompt,
    max_new_tokens=40,
    temperature=0.7,
    top_k=50,
    do_sample=True,
    num_return_sequences=1,
    pad_token_id=50256
)

# Print generated storyline
print("Generated Storyline:\n")
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'do_sample', 'pad_token_id', 'top_k', 'temperature', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated Storyline:
#
# The hero enters the ancient forest and discovers a large rock with a large stone blade. He can't hold his breath, but he manages to raise the stone that was holding the blade, and it flies away. When he finally reaches the stone

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)
token_ids = tokenizer.convert_tokens_to_ids(tokens)

print("Tokens:", tokens)
print("Token IDs:", token_ids)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Tokens: ['deep', 'learning', 'models', 'are', 'powerful']
# Token IDs: [2784, 4083, 4275, 2024, 3928]

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import BertTokenizer

# Load BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Patient query (sample text according to scenario)
text = "I have chest pain and shortness of breath"

# Tokenize the sentence
tokens = tokenizer.tokenize(text)

# Convert tokens into token IDs
token_ids = tokenizer.convert_tokens_to_ids(tokens)

# Print results
print("Patient Query:")
print(text)

print("\nTokens:")
print(tokens)

print("\nToken IDs:")
print(token_ids)
# Out:
# Patient Query:
# I have chest pain and shortness of breath
#
# Tokens:
# ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']
#
# Token IDs:
# [1045, 2031, 3108, 3255, 1998, 2460, 2791, 1997, 3052]

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

low_temp = generator(
    prompt,
    max_new_tokens=40,
    temperature=0.2
)

high_temp = generator(
    prompt,
    max_new_tokens=40,
    temperature=0.8
)

print("Low Temperature:\n", low_temp[0]["generated_text"])
print("\nHigh Temperature:\n", high_temp[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Low Temperature:
#  The future of Artificial Intelligence is in the hands of the next generation of AI.
#
# The future of AI is in the hands of the next generation of AI.
#
# The future of AI is in the hands of the
#
# High Temperature:
#  The future of Artificial Intelligence and the future of robotics? The Future of Brain Surgery. MIT Press, 2013.
#
# More on these topics below.

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling

# Scriptwriting Assistant for Film Production
# Demonstrating how temperature affects creativity in AI text generation

from transformers import pipeline

# Load GPT-2 text generation model
generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

#Low Temperature
low_output = generator(
    prompt,
    max_new_tokens=40,
    temperature=0.2,     
    do_sample=True,
    top_k=50,
    num_return_sequences=1
)

print("Temperature = 0.2 (Predictable Output)")
print(low_output[0]["generated_text"])


#High Temperature
high_output = generator(
    prompt,
    max_new_tokens=40,
    temperature=0.8,     
    top_p=0.9,           
    do_sample=True,
    num_return_sequences=1
)

print("\nTemperature = 0.8 (Creative Output)")
print(high_output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Passing `generation_config` together with generation-related arguments=({'top_p', 'max_new_tokens', 'do_sample', 'temperature', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Temperature = 0.2 (Predictable Output)
# The future of Artificial Intelligence is uncertain. In the meantime, we have to keep an eye on the future.
#
# The Future of Artificial Intelligence
#
# The future of artificial intelligence is uncertain. In the meantime, we have
#
# Temperature = 0.8 (Creative Output)
# The future of Artificial Intelligence and AI is still a very open area of research and development. The only way to learn from such research is through its methods and approaches. Artificial intelligence is a new field that may not yet be fully

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The future of Artificial Intelligence
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The future of Artificial Intelligence is being made more and more exciting by the fact that our ability to better understand people's minds, emotions and behaviors is now more relevant than ever, by which I mean with our ability to understand them. In my experience, this means having the ability to think, to imagine and to act and to think on our own. The reality is that we are still in the infancy stages of understanding how our brains work. What's interesting to me is that we are just beginning to understand how the brain works. We've been able to learn about the world around us from the brain. We've been able to better understand the brain and understand how our brains work. But what we're now seeing is that we're probably not used to being able to use what we've learned to understand people.
#
# What if we could just walk around and have a "mindset" that tells us, "I can understand the emotions of people, but I can't understand the thoughts of others"?
#
# That's a pretty hard thing to do. It should be a very simple thing. For example, we can say, "I can understand the emotions of people, but I can't understand the thoughts of others." The problem is that when you put something like that into a mind set

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”


# Install libraries if needed
# !pip install transformers torch

# Student Brainstorming Tool for Essay Writing

from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

# Load GPT-2 model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Avoid padding warnings
tokenizer.pad_token = tokenizer.eos_token

# Take input from user
prompt = input("Enter a prompt: ")

# Tokenize the input
inputs = tokenizer(prompt, return_tensors="pt")

# Generate text
output = model.generate(
    inputs["input_ids"],
    attention_mask=inputs["attention_mask"],
    max_new_tokens=50,
    do_sample=True,
    temperature=0.7,
    top_k=50,
    top_p=0.9,
    pad_token_id=tokenizer.eos_token_id
)

# Convert tokens to text
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print("\nGenerated Essay Idea:")
print(generated_text)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: the impact of technology on education
#
# Generated Essay Idea:
# the impact of technology on education. In this article we will discuss the impact of technology on education, and how the impact of technology affects the quality of the educational experience.
#
# What is the impact of technology on education?
#
# Technology is the most powerful and disruptive technology that

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform the way we think about what it means to be a human being.\n\nThe answer to the question of how to use AI in the workplace comes from a recent report by the Pew Research Center that found that just 15 percent of Americans want to see AI improve their job performance. A large majority of Americans believe AI will change the way we think about work, but those same Americans may be more worried about the future of the human race.\n\n"As we move toward a new era of automation and automation of jobs, it will be important for our leaders to look to the future of humanity," said the Pew Research Center\'s Mark Harris, "to see how this innovation could change the way we think about work and the way we talk about how technology can help us get out of this mess."'}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the public into a more intelligent, social, economic and moral society.\n\n\n\n“The first step in a process which will be a complete and universal revolution will take place in the coming years as the world’s largest information technology companies are expected to bring a huge audience of people to the world’s most important industries.”\nThe new technology will revolutionize communication between the world as it becomes more and more widely available, as the technology becomes more and more widely available.'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.

# Educational Tool for Classroom Learning
# Comparing GPT-2 and DistilGPT2 outputs

# Install if needed
# !pip install transformers torch

from transformers import pipeline

# Prompt used by teacher
prompt = "Artificial Intelligence will transform"

#GPT-2 Model
gpt2_generator = pipeline("text-generation", model="gpt2")

gpt2_output = gpt2_generator(
    prompt,
    max_new_tokens=40,
    temperature=0.7,
    do_sample=True
)

print("GPT-2 Output:")
print(gpt2_output[0]["generated_text"])


#DistilGPT2 Model
distil_generator = pipeline("text-generation", model="distilgpt2")

distil_output = distil_generator(
    prompt,
    max_new_tokens=40,
    temperature=0.7,
    do_sample=True
)

print("\nDistilGPT2 Output:")
print(distil_output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2 Output:
# Artificial Intelligence will transform the way companies use human intelligence in the future. But the question of whether an AI will lead to the greatest rise in innovation is still a matter of debate.
#
# The potential benefits of Artificial Intelligence
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# DistilGPT2 Output:
# Artificial Intelligence will transform the world for us.
